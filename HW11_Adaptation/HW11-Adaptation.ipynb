# %% [markdown]
# #  &#x1F4D1; **作业11： 迁移学习 (领域对抗性训练`Domain Adversarial Training`)**
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# 如果有任何问题, 联系 [mlta-2022-spring@googlegroups.com](mlta-2022-spring@googlegroups.com)

# %% [markdown]
# # Readme
#
# 在作业11中，你需要在迁移学习中进行领域对抗性训练。如图左下角所示。
#
# <img src="./HW11_pic/迁移学习中进行领域对抗性训练.jpg" width="500px">
#
# ## 场景和为什么领域对抗性训练
# 现在我们有打好标签的源数据以及未被标记目标的数据，其中源数据可能与目标数据相关。我们现在只想用源数据训练模型，并在目标数据上进行测试。
#
# 如果我们这样做，可能会出现什么问题？ 在我们学习了异常检测之后，我们现在知道，如果我们用源数据中从未出现过的异常数据来测试模型，我们训练的模型很可能会<font color=darkred>导致较差的性能</font>，因为它不熟悉异常数据。
#
# 例如，我们有一个包含特征提取器(`Feature Extractor`)和分类器(`Classifier`)的模型：
# <img src="./HW11_pic/特征提取器和分类器.jpg" width="500px">
#
# 模型使用源数据训练，特征提取器(`feature extractor`)会提取有意义的特征，因为它熟悉其分布。从下图中可以看出，蓝点是源数据的分布，已经被聚类为不同的聚类。因此，分类器可以基于这些聚类来预测标签。
# 然而, 在测试目标数据的时候， 特征提取器(`feature extractor`)将不能提取出和源数据相似分布的有意义特征，因为目标特征分布和源数据不一致。这导致为源数据学习出的分类器将不能应用于目标数据。
#
# ## 神经网络的领域对抗训练（`Domain Adversarial Training of Nerural Networks (DaNN)`)
#
# 基于上述问题, DaNN方法在源（训练时间）域和目标（测试时间）域之间建立映射，因此，当与域之间的学习映射相结合时，用源数据学习的分类器也可以应用于目标数据。
#
# <img src="./HW11_pic/DaNN.jpg" width="500px">
#
# 在DaNN中, 作者增加了一个域分类器(`Domain Classifier`),  它是训练框架中经过深度判别训练的分类器(`discriminatively-trained classifeir`)，通过特征提取器提取的特征来区分来自不同领域的数据。随着训练的进行，该方法促进了区分源域和目标域的域分类器，以及特征提取器可以对源数据上主要学习任务具有判别力的特征进行提取，同时对域之间的偏移不加区分的特征进行提取。
#
# 特征提取器可能优于域分类器，因为域分类器输入是由特征提取器生成的，并且域分类和标签分类的任务不冲突。
#
# 这种方法导致特征具有区域不变性和相同的特征分布。

# %% [markdown]
# # 数据介绍
#
# 源数据(`source data`): 真实照片,
# 目标数据(`target data`): 手绘涂鸦
#
# 用真实照片和label进行模型训练, 然后尝试对 手绘涂鸦 进行识别类型.
#
# 数据下载地址： [here](https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip).
# 下面的代码是数据下载和简单可视化
# 提示: **源数据和目标数据都是平衡数据，您可以利用这些信息.**

# %%
# Download dataset
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.0/real_or_drawing.zip" -O real_or_drawing.zip

# Download from mirrored dataset link
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.1/real_or_drawing.zip" -O real_or_drawing.zip
# !wget "https://github.com/redxouls/ml2020spring-hw11-dataset/releases/download/v1.0.2/real_or_drawing.zip" -O real_or_drawing.zip

# Unzip the files
# !unzip real_or_drawing.zip

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
    fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
    fig.axes.get_xaxis().set_visible(False)
    fig.axes.get_yaxis().set_visible(False)
    plt.title(title)

# %%
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'tetevision', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 4))
for i in range(10):
    plt.subplot(2, 10, i+1)
    fig = no_axis_show(plt.imread(f'real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

for i in range(10):
    plt.subplot(2, 10, 10+i+1)
    fig = no_axis_show(plt.imread(f'real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

plt.show()

# %% [markdown]
# # 特殊领域知识
#
# 涂鸦时，通常只画出轮廓，因此可以对源数据进行边缘检测处理，使其更接近目标数据。
#
#
# ## Canny边缘提取
# Canny边缘检测的实现方法如下。
# 算法的具体原理大家可以自行查阅，可以参考wilki或者是这篇博客 [Canny edge detector 實作](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19).
#
# 用CV2实现Canny边缘检测只需要两个参数：`low_threshold` and `high_threshold`.
# 示例代码如下：
# ```python
# cv2.Canny(image, low_threshold, high_threshold)
# ```
# 简单地说，当边值超过`high_threshold`阈值时，我们将其确定为边。如果边值**仅**高于`low_threshold`阈值，我们将确定它是否为边缘。
# 让我们在源数据上实现它。

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

# %% [markdown]
# #  &#x2728; 数据处理
#
# 此数据适用于`torchvision.ImageFolder`。您可以使用`torchvision.ImageFolder`创建数据集。有关图像增强的详细信息，请参阅以下代码中的注释。

# %%
import numpy as np
import torch
from torch import nn
from torch.nn import functional as F
from torch.autograd import Function
from torch import optim 
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader


src_transform = transforms.Compose([
    # 将 RGB  转换成 greyscale
    transforms.Grayscale(),
    # cv2 不支持 skimage.Image, 需要先装换成 np.array 并采用 cv2.Canny 算法
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), 170, 300)),
    # np.array -> skimag.Image
    transforms.ToPILImage(),
    # 50% 水平翻转(数据增强)
    transforms.RandomHorizontalFlip(),
    # 旋转 +- 15 度,并对旋转后空缺的地方填充0 
    transforms.RandomRotation(15, fill=(0,)),
    # 转成tensor 作为模型输入
    transforms.ToTensor(),
])

# 区别是不进行 Canny 识别轮廓
tgt_transform = transforms.Compose([
    transforms.Grayscale(),
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15, fill=(0,)),
    transforms.ToTensor(),

])

source_dataset = ImageFolder('real_or_drawing/train_data', transform=src_transform)
target_dataset = ImageFolder('real_or_drawing/test_data', transform=tgt_transform)

source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# #  &#x2728;  模型
#
# - 特征提取器`Feature Extractor`: 经典的VGG式体系结构
# - 分类器`Label Predictor / Domain Classifier`: 线性模型.

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),
            
            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),
            
            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
    
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x
    

class LabelPredictor(nn.Module):
    def __init__(self):
        super(LabelPredictor, self).__init__()
        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )
        
    def forward(self, x):
        x = self.layer(x)
        return x
    

class DomainClassifier(nn.Module):
    def __init__(self):
        super(DomainClassifier, self).__init__()
        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )
        
    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # 预处理
#
# 优化器： Adam

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())

# %% [markdown]
# #  &#x2728; 开始训练
#
#
# ## DaNN实施
#
# 在原始论文中，使用了渐变反转层(` Gradient Reversal Layer`)。特征提取器`Feature Extractor`, 分类器`Label Predictor`, 和域分类器`Domain Classifier` 同时训练.
# 在我们的代码中，我们先训练域分类器`Domain Classifier`，然后训练我们的特征提取器`Feature Extractor`和`Label Predictor`（与GAN中的生成器和判别器训练过程相同的概念）
#
# ## 提醒
# * Lambda, 控制领域对抗性损失，在原始论文中是自适应的. 你可以参考论文[Domain-Adversarial Training of Neural Networks](https://arxiv.org/pdf/1505.07818.pdf) . 这里我们设置 `lambda = 0.1`.
# * 目标数据上没有标签, 您只能通过将结果上传到kaggle来评估您的模型. :)

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: 控制域自适应(domain adaptatoin) 和分类的平衡
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0
    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):
        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        # 混合 source data 和 target data,否则会误导正在运行的batch_norm的参数(运行源数据和目标数据的 mean/var 不同)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # 设置域标签，源数据标签设为1
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : 训练 domain classifier
        feature = feature_extractor(mixed_data)
        # 在第一部我们不需要训练特征提取器，所以需要对特征进行 .detach() 操作，防止反向传播
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss += loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : 训练 feature extractor 和 label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = label分类损失 - lamb * 域分类损失.
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss += loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()

        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r')
        
    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

# 训练200 epoch
for epoch in range(200):
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=0.1)

    torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
    torch.save(label_predictor.state_dict(), f'predictor_model.bin')

    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}'.format(epoch, train_D_loss, train_F_loss, train_acc))
# Out:
# epoch   0: train D loss: 0.7174, train F loss: 1.9258, acc 0.2558
# epoch   1: train D loss: 0.6566, train F loss: 1.6126, acc 0.3912
# epoch   2: train D loss: 0.5773, train F loss: 1.4690, acc 0.4718
# epoch   3: train D loss: 0.5476, train F loss: 1.3783, acc 0.4970
# epoch   4: train D loss: 0.5322, train F loss: 1.3079, acc 0.5256
# epoch   5: train D loss: 0.5438, train F loss: 1.2591, acc 0.5410
# epoch   6: train D loss: 0.5404, train F loss: 1.2237, acc 0.5564
# epoch   7: train D loss: 0.5261, train F loss: 1.1858, acc 0.5746
# epoch   8: train D loss: 0.5192, train F loss: 1.1488, acc 0.5786
# epoch   9: train D loss: 0.5228, train F loss: 1.0954, acc 0.5980
# epoch  10: train D loss: 0.5190, train F loss: 1.0862, acc 0.6082
# epoch  11: train D loss: 0.5258, train F loss: 1.0434, acc 0.6226
# epoch  12: train D loss: 0.5202, train F loss: 0.9998, acc 0.6350
# epoch  13: train D loss: 0.5335, train F loss: 0.9584, acc 0.6430
# epoch  14: train D loss: 0.5268, train F loss: 0.9410, acc 0.6544
# epoch  15: train D loss: 0.5236, train F loss: 0.8976, acc 0.6662
# epoch  16: train D loss: 0.5214, train F loss: 0.8582, acc 0.6826
# epoch  17: train D loss: 0.5049, train F loss: 0.8183, acc 0.7004
# epoch  18: train D loss: 0.5214, train F loss: 0.8169, acc 0.7006
# epoch  19: train D loss: 0.5106, train F loss: 0.7570, acc 0.7168
# epoch  20: train D loss: 0.5050, train F loss: 0.7412, acc 0.7214
# epoch  21: train D loss: 0.4705, train F loss: 0.7087, acc 0.7374
# epoch  22: train D loss: 0.4903, train F loss: 0.6629, acc 0.7484
# epoch  23: train D loss: 0.4716, train F loss: 0.6445, acc 0.7586
# epoch  24: train D loss: 0.4919, train F loss: 0.6138, acc 0.7764
# epoch  25: train D loss: 0.4668, train F loss: 0.5830, acc 0.7868
# epoch  26: train D loss: 0.4754, train F loss: 0.5542, acc 0.8006
# epoch  27: train D loss: 0.4578, train F loss: 0.5174, acc 0.8086
# epoch  28: train D loss: 0.4723, train F loss: 0.4831, acc 0.8204
# epoch  29: train D loss: 0.4482, train F loss: 0.4790, acc 0.8218
# epoch  30: train D loss: 0.4478, train F loss: 0.4509, acc 0.8326
# epoch  31: train D loss: 0.4338, train F loss: 0.4111, acc 0.8470
# epoch  32: train D loss: 0.4404, train F loss: 0.3906, acc 0.8532
# epoch  33: train D loss: 0.4476, train F loss: 0.3834, acc 0.8570
# epoch  34: train D loss: 0.4271, train F loss: 0.3723, acc 0.8594
# epoch  35: train D loss: 0.4279, train F loss: 0.3514, acc 0.8648
# epoch  36: train D loss: 0.4092, train F loss: 0.3316, acc 0.8754
# epoch  37: train D loss: 0.4105, train F loss: 0.3199, acc 0.8760
# epoch  38: train D loss: 0.4072, train F loss: 0.2890, acc 0.8880
# epoch  39: train D loss: 0.4243, train F loss: 0.2804, acc 0.8908
# epoch  40: train D loss: 0.4094, train F loss: 0.2779, acc 0.8912
# epoch  41: train D loss: 0.3981, train F loss: 0.2756, acc 0.8956
# epoch  42: train D loss: 0.3995, train F loss: 0.2728, acc 0.8958
# epoch  43: train D loss: 0.3861, train F loss: 0.2381, acc 0.9112
# epoch  44: train D loss: 0.4058, train F loss: 0.2109, acc 0.9194
# epoch  45: train D loss: 0.4008, train F loss: 0.2240, acc 0.9160
# epoch  46: train D loss: 0.4017, train F loss: 0.2124, acc 0.9120
# epoch  47: train D loss: 0.3993, train F loss: 0.2014, acc 0.9180
# epoch  48: train D loss: 0.4019, train F loss: 0.1943, acc 0.9200
# epoch  49: train D loss: 0.3996, train F loss: 0.1724, acc 0.9280
# epoch  50: train D loss: 0.3852, train F loss: 0.1618, acc 0.9374
# epoch  51: train D loss: 0.3995, train F loss: 0.1902, acc 0.9250
# epoch  52: train D loss: 0.3991, train F loss: 0.1699, acc 0.9306
# epoch  53: train D loss: 0.3806, train F loss: 0.1628, acc 0.9340
# epoch  54: train D loss: 0.3911, train F loss: 0.1411, acc 0.9384
# epoch  55: train D loss: 0.3894, train F loss: 0.1441, acc 0.9392
# epoch  56: train D loss: 0.3987, train F loss: 0.1531, acc 0.9356
# epoch  57: train D loss: 0.3949, train F loss: 0.1493, acc 0.9396
# epoch  58: train D loss: 0.3844, train F loss: 0.1349, acc 0.9394
# epoch  59: train D loss: 0.3887, train F loss: 0.1356, acc 0.9432
# epoch  60: train D loss: 0.3870, train F loss: 0.1105, acc 0.9508
# epoch  61: train D loss: 0.3992, train F loss: 0.1309, acc 0.9452
# epoch  62: train D loss: 0.3981, train F loss: 0.1319, acc 0.9442
# epoch  63: train D loss: 0.3867, train F loss: 0.1257, acc 0.9470
# epoch  64: train D loss: 0.3821, train F loss: 0.1323, acc 0.9424
# epoch  65: train D loss: 0.3898, train F loss: 0.1215, acc 0.9460
# epoch  66: train D loss: 0.3839, train F loss: 0.1237, acc 0.9444
# epoch  67: train D loss: 0.3867, train F loss: 0.1160, acc 0.9490
# epoch  68: train D loss: 0.3859, train F loss: 0.1116, acc 0.9486
# epoch  69: train D loss: 0.3756, train F loss: 0.1064, acc 0.9532
# epoch  70: train D loss: 0.3957, train F loss: 0.1039, acc 0.9530
# epoch  71: train D loss: 0.3885, train F loss: 0.1116, acc 0.9524
# epoch  72: train D loss: 0.3651, train F loss: 0.0954, acc 0.9542
# epoch  73: train D loss: 0.3840, train F loss: 0.0875, acc 0.9572
# epoch  74: train D loss: 0.3886, train F loss: 0.0931, acc 0.9552
# epoch  75: train D loss: 0.3898, train F loss: 0.0886, acc 0.9576
# epoch  76: train D loss: 0.3769, train F loss: 0.0943, acc 0.9560
# epoch  77: train D loss: 0.3874, train F loss: 0.0928, acc 0.9548
# epoch  78: train D loss: 0.3938, train F loss: 0.1075, acc 0.9528
# epoch  79: train D loss: 0.3810, train F loss: 0.0917, acc 0.9550
# epoch  80: train D loss: 0.3884, train F loss: 0.0736, acc 0.9624
# epoch  81: train D loss: 0.3964, train F loss: 0.0836, acc 0.9584
# epoch  82: train D loss: 0.3888, train F loss: 0.0760, acc 0.9586
# epoch  83: train D loss: 0.3755, train F loss: 0.0903, acc 0.9596
# epoch  84: train D loss: 0.3722, train F loss: 0.0686, acc 0.9660
# epoch  85: train D loss: 0.3746, train F loss: 0.0770, acc 0.9616
# epoch  86: train D loss: 0.3719, train F loss: 0.0870, acc 0.9610
# epoch  87: train D loss: 0.3717, train F loss: 0.0874, acc 0.9608
# epoch  88: train D loss: 0.3544, train F loss: 0.0625, acc 0.9676
# epoch  89: train D loss: 0.3806, train F loss: 0.0698, acc 0.9646
# epoch  90: train D loss: 0.3810, train F loss: 0.0963, acc 0.9584
# epoch  91: train D loss: 0.3838, train F loss: 0.0701, acc 0.9628
# epoch  92: train D loss: 0.3682, train F loss: 0.0883, acc 0.9610
# epoch  93: train D loss: 0.3665, train F loss: 0.1057, acc 0.9564
# epoch  94: train D loss: 0.3728, train F loss: 0.0704, acc 0.9648
# epoch  95: train D loss: 0.3780, train F loss: 0.0422, acc 0.9730
# epoch  96: train D loss: 0.3797, train F loss: 0.0390, acc 0.9754
# epoch  97: train D loss: 0.3751, train F loss: 0.0833, acc 0.9610
# epoch  98: train D loss: 0.3751, train F loss: 0.0637, acc 0.9678
# epoch  99: train D loss: 0.3914, train F loss: 0.0636, acc 0.9666
# epoch 100: train D loss: 0.3786, train F loss: 0.0586, acc 0.9686
# epoch 101: train D loss: 0.3746, train F loss: 0.0615, acc 0.9698
# epoch 102: train D loss: 0.3802, train F loss: 0.0650, acc 0.9658
# epoch 103: train D loss: 0.3884, train F loss: 0.0595, acc 0.9684
# epoch 104: train D loss: 0.3774, train F loss: 0.0544, acc 0.9706
# epoch 105: train D loss: 0.3808, train F loss: 0.0537, acc 0.9720
# epoch 106: train D loss: 0.3796, train F loss: 0.0530, acc 0.9712
# epoch 107: train D loss: 0.3836, train F loss: 0.0498, acc 0.9700
# epoch 108: train D loss: 0.3847, train F loss: 0.0613, acc 0.9670
# epoch 109: train D loss: 0.3737, train F loss: 0.0693, acc 0.9682
# epoch 110: train D loss: 0.3809, train F loss: 0.0411, acc 0.9708
# epoch 111: train D loss: 0.3766, train F loss: 0.0565, acc 0.9708
# epoch 112: train D loss: 0.3840, train F loss: 0.0534, acc 0.9692
# epoch 113: train D loss: 0.3831, train F loss: 0.0411, acc 0.9764
# epoch 114: train D loss: 0.3774, train F loss: 0.0649, acc 0.9684
# epoch 115: train D loss: 0.3751, train F loss: 0.0493, acc 0.9736
# epoch 116: train D loss: 0.3877, train F loss: 0.0512, acc 0.9706
# epoch 117: train D loss: 0.3790, train F loss: 0.0592, acc 0.9704
# epoch 118: train D loss: 0.3749, train F loss: 0.0537, acc 0.9702
# epoch 119: train D loss: 0.3880, train F loss: 0.0483, acc 0.9720
# epoch 120: train D loss: 0.3820, train F loss: 0.0455, acc 0.9736
# epoch 121: train D loss: 0.3701, train F loss: 0.0485, acc 0.9696
# epoch 122: train D loss: 0.3711, train F loss: 0.0641, acc 0.9674
# epoch 123: train D loss: 0.3738, train F loss: 0.0486, acc 0.9722
# epoch 124: train D loss: 0.3755, train F loss: 0.0438, acc 0.9770
# epoch 125: train D loss: 0.3868, train F loss: 0.0413, acc 0.9750
# epoch 126: train D loss: 0.3839, train F loss: 0.0427, acc 0.9758
# epoch 127: train D loss: 0.3849, train F loss: 0.0471, acc 0.9734
# epoch 128: train D loss: 0.3846, train F loss: 0.0409, acc 0.9772
# epoch 129: train D loss: 0.3949, train F loss: 0.0461, acc 0.9720
# epoch 130: train D loss: 0.3742, train F loss: 0.0536, acc 0.9688
# epoch 131: train D loss: 0.3701, train F loss: 0.0359, acc 0.9764
# epoch 132: train D loss: 0.3882, train F loss: 0.0431, acc 0.9752
# epoch 133: train D loss: 0.3879, train F loss: 0.0235, acc 0.9794
# epoch 134: train D loss: 0.3902, train F loss: 0.0354, acc 0.9756
# epoch 135: train D loss: 0.3890, train F loss: 0.0451, acc 0.9736
# epoch 136: train D loss: 0.3735, train F loss: 0.0513, acc 0.9710
# epoch 137: train D loss: 0.3748, train F loss: 0.0357, acc 0.9740
# epoch 138: train D loss: 0.3827, train F loss: 0.0418, acc 0.9720
# epoch 139: train D loss: 0.3602, train F loss: 0.0381, acc 0.9796
# epoch 140: train D loss: 0.3852, train F loss: 0.0541, acc 0.9726
# epoch 141: train D loss: 0.3652, train F loss: 0.0408, acc 0.9774
# epoch 142: train D loss: 0.3862, train F loss: 0.0276, acc 0.9804
# epoch 143: train D loss: 0.3828, train F loss: 0.0270, acc 0.9778
# epoch 144: train D loss: 0.3958, train F loss: 0.0185, acc 0.9808
# epoch 145: train D loss: 0.3868, train F loss: 0.0487, acc 0.9700
# epoch 146: train D loss: 0.3891, train F loss: 0.0378, acc 0.9770
# epoch 147: train D loss: 0.3730, train F loss: 0.0379, acc 0.9766
# epoch 148: train D loss: 0.3671, train F loss: 0.0354, acc 0.9764
# epoch 149: train D loss: 0.3857, train F loss: 0.0378, acc 0.9766
# epoch 150: train D loss: 0.3881, train F loss: 0.0361, acc 0.9780
# epoch 151: train D loss: 0.3784, train F loss: 0.0242, acc 0.9822
# epoch 152: train D loss: 0.3952, train F loss: 0.0303, acc 0.9782
# epoch 153: train D loss: 0.3952, train F loss: 0.0335, acc 0.9764
# epoch 154: train D loss: 0.3900, train F loss: 0.0261, acc 0.9802
# epoch 155: train D loss: 0.3833, train F loss: 0.0298, acc 0.9788
# epoch 156: train D loss: 0.3878, train F loss: 0.0531, acc 0.9728
# epoch 157: train D loss: 0.4002, train F loss: 0.0339, acc 0.9766
# epoch 158: train D loss: 0.3796, train F loss: 0.0318, acc 0.9774
# epoch 159: train D loss: 0.3806, train F loss: 0.0251, acc 0.9806
# epoch 160: train D loss: 0.3661, train F loss: 0.0204, acc 0.9810
# epoch 161: train D loss: 0.4056, train F loss: 0.0293, acc 0.9776
# epoch 162: train D loss: 0.3731, train F loss: 0.0616, acc 0.9698
# epoch 163: train D loss: 0.3820, train F loss: 0.0287, acc 0.9784
# epoch 164: train D loss: 0.3792, train F loss: 0.0322, acc 0.9796
# epoch 165: train D loss: 0.3732, train F loss: 0.0295, acc 0.9784
# epoch 166: train D loss: 0.3805, train F loss: 0.0258, acc 0.9770
# epoch 167: train D loss: 0.3829, train F loss: 0.0146, acc 0.9840
# epoch 168: train D loss: 0.3856, train F loss: 0.0211, acc 0.9810
# epoch 169: train D loss: 0.3964, train F loss: 0.0258, acc 0.9784
# epoch 170: train D loss: 0.3755, train F loss: 0.0184, acc 0.9804
# epoch 171: train D loss: 0.3911, train F loss: 0.0178, acc 0.9844
# epoch 172: train D loss: 0.3817, train F loss: 0.0243, acc 0.9796
# epoch 173: train D loss: 0.3820, train F loss: 0.0404, acc 0.9764
# epoch 174: train D loss: 0.3871, train F loss: 0.0346, acc 0.9806
# epoch 175: train D loss: 0.3910, train F loss: 0.0264, acc 0.9792
# epoch 176: train D loss: 0.3847, train F loss: 0.0189, acc 0.9842
# epoch 177: train D loss: 0.3847, train F loss: 0.0269, acc 0.9808
# epoch 178: train D loss: 0.3899, train F loss: 0.0194, acc 0.9806
# epoch 179: train D loss: 0.3954, train F loss: 0.0094, acc 0.9848
# epoch 180: train D loss: 0.4035, train F loss: 0.0255, acc 0.9818
# epoch 181: train D loss: 0.4009, train F loss: 0.0362, acc 0.9738
# epoch 182: train D loss: 0.3884, train F loss: 0.0320, acc 0.9750
# epoch 183: train D loss: 0.3970, train F loss: 0.0198, acc 0.9818
# epoch 184: train D loss: 0.3943, train F loss: 0.0175, acc 0.9818
# epoch 185: train D loss: 0.3930, train F loss: 0.0254, acc 0.9798
# epoch 186: train D loss: 0.3896, train F loss: 0.0265, acc 0.9804
# epoch 187: train D loss: 0.3826, train F loss: 0.0142, acc 0.9826
# epoch 188: train D loss: 0.3780, train F loss: 0.0226, acc 0.9806
# epoch 189: train D loss: 0.3979, train F loss: 0.0159, acc 0.9824
# epoch 190: train D loss: 0.3918, train F loss: 0.0146, acc 0.9838
# epoch 191: train D loss: 0.3876, train F loss: 0.0113, acc 0.9844
# epoch 192: train D loss: 0.4039, train F loss: 0.0103, acc 0.9836
# epoch 193: train D loss: 0.3946, train F loss: 0.0252, acc 0.9804
# epoch 194: train D loss: 0.3741, train F loss: 0.0268, acc 0.9784
# epoch 195: train D loss: 0.4002, train F loss: 0.0306, acc 0.9774
# epoch 196: train D loss: 0.3969, train F loss: 0.0302, acc 0.9798
# epoch 197: train D loss: 0.4008, train F loss: 0.0188, acc 0.9816
# epoch 198: train D loss: 0.4050, train F loss: 0.0174, acc 0.9812
# epoch 199: train D loss: 0.4003, train F loss: 0.0270, acc 0.9788

# %% [markdown]
# # 预测推理
#
# 我们使用 pandas 生成csv文件
#
# 顺便说一句，经过200个时期训练的模型的性能可能不稳定。你可以为更稳定的表现训练更多的时期。

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()
    class_logits = label_predictor(feature_extractor(test_data))
    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# 生成提交文件
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)

# %% [markdown]
# #  &#x2728; 可视化
# 我们使用t-SNE图来观察提取的特征的分布

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import manifold

# %% [markdown]
# ## Step1: 加载检查点并进行评估以获得提取的特征

# %%
# Hints:
# 设置 features_extractor 为 eval 模型
# 开始评估并收集特征和标签
from tqdm import tqdm
feature_extractor.eval()
feat_list = []
label_list = []
for i, (source_data, source_label) in enumerate(tqdm(source_dataloader)):
    source_data = source_data.cuda()
    source_label = source_label.cuda()
    feat = feature_extractor(source_data).cpu().detach().numpy()
    label_list.append(source_label.cpu().detach().numpy())
    feat_list.append(feat)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 157/157 [00:05<00:00, 28.81it/s]

# %%
labels = np.concatenate(label_list)
labels.shape
# Out:
# (5000,)

# %%
feats = np.concatenate(feat_list)
feats.shape
# Out:
# (5000, 512)

# %% [markdown]
# ## Step2: 运用 t-SNE 并进行归一化

# %%
# process extracted features with t-SNE
X_tsne = manifold.TSNE(n_components=2, init='random', random_state=5, verbose=1).fit_transform(feats)

# Normalization the processed features 
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)
# Out:
# G:\Anaconda3\envs\pytorch\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.003s...
# [t-SNE] Computed neighbors for 5000 samples in 0.669s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.786929
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.992561
# [t-SNE] KL divergence after 1000 iterations: 1.699536

# %%
import seaborn as sns
sne_df = pd.DataFrame(X_norm, columns=['f1', 'f2'])
sne_df['label'] = labels

# %%
sns.scatterplot(data=sne_df, x='f1', y='f2', hue='label')
plt.show()

# %% [markdown]
# # 训练统计
# - 参数量:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # 学习率曲线 (Strong Baseline)
# * 这种方法与colab略有不同。
#
# ![Loss Curve](./HW11_pic/loss.jpg)
#
# # 精度曲线 (Strong Baseline)
# * 请注意，您无法访问测试准确性。但这张图告诉，即使模型超过了训练数据，测试精度仍在提高，这就是为什么需要训练更多时间的原因。
#
# ![Acc Curve](./HW11_pic/acc.jpg)

# %% [markdown]
# # Q&A
#
# 如果有任何与域适配相关的问题，请发送电子邮件至 b08901058@ntu.edu.tw / mlta-2022-spring@googlegroups.com。
